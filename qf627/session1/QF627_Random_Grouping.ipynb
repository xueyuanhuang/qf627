# %% [markdown]
# # QF 627 Programming and Computational Finance
# ### Random Assignment for Take-Home Assignment Task

# %%
import random
import pandas as pd

# %%
roster = pd.read_csv("qf627_g1.csv")
roster
# Out:
#                              name
# 0                   LEONG YU RONG
# 1            SOH GIAP HONG DANIEL
# 2                   CHEN LIANGRUI
# 3                      LIU YIXUAN
# 4               DENTON TNG JIA LE
# 5          NADEZHDA KHUSNETDINOVA
# 6       DURGHESHWARI DO ELAMURUGU
# 7           HUANG RUIZHI SUNSHINE
# 8                    ZHAO JIANKUN
# 9                     SIM KIM WEE
# 10                        YAN JUN
# 11                  LEE MENG-TING
# 12                 ZHANG SHUOYUAN
# 13                   LU CHENG-YEN
# 14                TOM TAN ZHE JIE
# 15          DARREN CHAN YUK TSING
# 16                    ZHOU TIANQI
# 17                   KHOR SHUO EN
# 18                  HUANG WENYING
# 19                   LEE KAI SHAN
# 20                    REN LINGRAN
# 21                   WONG KEAT YE
# 22                     LI LINGWEI
# 23                   WANG HAOTONG
# 24           PRASAD POPAT DHAMANE
# 25                       XIA TIAN
# ...

# %%
students = roster["name"].tolist()

# %%
random.seed(20230822)

# %%
members_per_group = 6

# %%
group = 1

for s in students[:]:
    if members_per_group == 6:
        print("***** Group {} *****".format(group)
             ) 
        members_per_group = 0
        group += 1
    
    student = random.choice(students)
    
    print(student)
    
    members_per_group += 1
    
    students.remove(str(student)
                   )
# Out:
# ***** Group 1 *****
# DENG KE
# LI ZICONG
# LIU JING
# WANG WENJIE
# YU LINGFENG
# CHEN ZHIYUAN
# ***** Group 2 *****
# GUPTA DEVANSH
# SHARON GAUTAMA
# TSENG HONG KAI
# DARREN CHAN YUK TSING
# ZHANG SHUOYUAN
# LIU YIXUAN
# ***** Group 3 *****
# YOON SUNIL
# DENTON TNG JIA LE
# SSHUBH NAIK
# KRISH ATUL SHAH
# LEI YUMING
# ZHOU TIANQI
# ***** Group 4 *****
# LI ZEHAO
# REN LINGRAN
# YAN JUN
# MUHAMMAD SYAIRAZI BIN MAHDHAR
# YU CHUNXUE
# JIANG ZIHAN
# ***** Group 5 *****
# PRASAD POPAT DHAMANE
# HUANG ZIYAN
# NADEZHDA KHUSNETDINOVA
# SUGINTHA SIVANESWARAN
# SOH GIAP HONG DANIEL
# TOM TAN ZHE JIE
# ***** Group 6 *****
# CAI YIHAN
# LI LINGWEI
# CHEN LIANGRUI
# ZHAO JIANKUN
# LEE MENG-TING
# HUANG WENYING
# ***** Group 7 *****
# HUANG RUIZHI SUNSHINE
# WANG HAOTONG
# KHOR SHUO EN
# LEE KAI SHAN
# LU CHENG-YEN
# XU XUANTAO
# ***** Group 8 *****
# VARUN ASHISH CHITALIA
# WONG KEAT YE
# ZHANG KEKE
# ZHANG MENGQI
# URVAANSH BAID
# LEONG YU RONG
# ***** Group 9 *****
# MAI JIALING
# ...

# %%
# %whos
# Out:
# Variable            Type         Data/Info
# ------------------------------------------
# group               int          11
# high_kurt           float        2.371214235565402
# high_kurt_pdf       ndarray      1000: 1000 elems, type `float64`, 8000 bytes
# kurtosis            function     <function kurtosis at 0x000002A85B9B8AE0>
# low_kurt            float        1.1700851388081093
# low_kurt_pdf        ndarray      1000: 1000 elems, type `float64`, 8000 bytes
# members_per_group   int          4
# norm                norm_gen     <scipy.stats._continuous_<...>ct at 0x000002A859466850>
# normal_kurt         float        -0.30739308774220664
# normal_pdf          ndarray      1000: 1000 elems, type `float64`, 8000 bytes
# np                  module       <module 'numpy' from 'E:\<...>ges\\numpy\\__init__.py'>
# pd                  module       <module 'pandas' from 'E:<...>es\\pandas\\__init__.py'>
# ...

# %%
import pandas as pd
import random

# %%
students = pd.read_csv("qf627_g1.csv")
students
# Out:
#                              name
# 0                   LEONG YU RONG
# 1            SOH GIAP HONG DANIEL
# 2                   CHEN LIANGRUI
# 3                      LIU YIXUAN
# 4               DENTON TNG JIA LE
# 5          NADEZHDA KHUSNETDINOVA
# 6       DURGHESHWARI DO ELAMURUGU
# 7           HUANG RUIZHI SUNSHINE
# 8                    ZHAO JIANKUN
# 9                     SIM KIM WEE
# 10                        YAN JUN
# 11                  LEE MENG-TING
# 12                 ZHANG SHUOYUAN
# 13                   LU CHENG-YEN
# 14                TOM TAN ZHE JIE
# 15          DARREN CHAN YUK TSING
# 16                    ZHOU TIANQI
# 17                   KHOR SHUO EN
# 18                  HUANG WENYING
# 19                   LEE KAI SHAN
# 20                    REN LINGRAN
# 21                   WONG KEAT YE
# 22                     LI LINGWEI
# 23                   WANG HAOTONG
# 24           PRASAD POPAT DHAMANE
# 25                       XIA TIAN
# ...

# %%
students = students["name"].tolist()

# %%
random.seed(20230822)

# %%
members_per_group = 6

# %%
group = 1

for i in students[:]:
    if members_per_group == 6:
        print("******group {}******".format(group))
        
        members_per_group = 0
        group += 1
    
    student = random.choice(students)
    print(student)
    members_per_group += 1
    
    students.remove(student)
# Out:
# ******group 1******
# DENG KE
# LI ZICONG
# LIU JING
# WANG WENJIE
# YU LINGFENG
# CHEN ZHIYUAN
# ******group 2******
# GUPTA DEVANSH
# SHARON GAUTAMA
# TSENG HONG KAI
# DARREN CHAN YUK TSING
# ZHANG SHUOYUAN
# LIU YIXUAN
# ******group 3******
# YOON SUNIL
# DENTON TNG JIA LE
# SSHUBH NAIK
# KRISH ATUL SHAH
# LEI YUMING
# ZHOU TIANQI
# ******group 4******
# LI ZEHAO
# REN LINGRAN
# YAN JUN
# MUHAMMAD SYAIRAZI BIN MAHDHAR
# YU CHUNXUE
# JIANG ZIHAN
# ******group 5******
# PRASAD POPAT DHAMANE
# HUANG ZIYAN
# NADEZHDA KHUSNETDINOVA
# SUGINTHA SIVANESWARAN
# SOH GIAP HONG DANIEL
# TOM TAN ZHE JIE
# ******group 6******
# CAI YIHAN
# LI LINGWEI
# CHEN LIANGRUI
# ZHAO JIANKUN
# LEE MENG-TING
# HUANG WENYING
# ******group 7******
# HUANG RUIZHI SUNSHINE
# WANG HAOTONG
# KHOR SHUO EN
# LEE KAI SHAN
# LU CHENG-YEN
# XU XUANTAO
# ******group 8******
# VARUN ASHISH CHITALIA
# WONG KEAT YE
# ZHANG KEKE
# ZHANG MENGQI
# URVAANSH BAID
# LEONG YU RONG
# ******group 9******
# MAI JIALING
# ...

# %% [markdown]
# ### YAY~ I wish you the best for the problem-solving exercise, Team :)
